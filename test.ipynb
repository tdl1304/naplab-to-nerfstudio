# %%
import glob, os

# %%
print(glob.glob("gnss/images/*.png"))
# Out:
# ['gnss/images/0_1449.png', 'gnss/images/0_3609.png', 'gnss/images/0_3639.png', 'gnss/images/0_1179.png', 'gnss/images/0_2829.png', 'gnss/images/0_3459.png', 'gnss/images/0_699.png', 'gnss/images/0_4659.png', 'gnss/images/0_3729.png', 'gnss/images/0_4269.png', 'gnss/images/0_579.png', 'gnss/images/0_4899.png', 'gnss/images/0_1479.png', 'gnss/images/0_3069.png', 'gnss/images/0_4929.png', 'gnss/images/0_1989.png', 'gnss/images/0_159.png', 'gnss/images/0_2709.png', 'gnss/images/0_4209.png', 'gnss/images/0_1569.png', 'gnss/images/0_2199.png', 'gnss/images/0_909.png', 'gnss/images/0_1329.png', 'gnss/images/0_3369.png', 'gnss/images/0_2229.png', 'gnss/images/0_2439.png', 'gnss/images/0_1509.png', 'gnss/images/0_2139.png', 'gnss/images/0_459.png', 'gnss/images/0_999.png', 'gnss/images/0_4839.png', 'gnss/images/0_1359.png', 'gnss/images/0_4389.png', 'gnss/images/0_609.png', 'gnss/images/0_1749.png', 'gnss/images/0_4959.png', 'gnss/images/0_1389.png', 'gnss/images/0_2679.png', 'gnss/images/0_5
# ...

# %%
from pathlib import Path
from PIL import Image


image_paths = list(map(lambda file: Image.open(Path(file)), glob.glob("gnss/images/*.png")))
print(image_paths)
# Out:
# [<PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1208 at 0x7F126C2A2880>, <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1208 at 0x7F12645B0A30>, <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1208 at 0x7F12645BC4C0>, <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1208 at 0x7F12645BC610>, <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1208 at 0x7F12645BC5E0>, <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1208 at 0x7F12645BC400>, <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1208 at 0x7F12645BC730>, <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1208 at 0x7F12645BC880>, <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1208 at 0x7F12645BC9D0>, <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1208 at 0x7F12645BCB20>, <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1208 at 0x7F12645BCC70>, <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1208 at 0x7F12645BCDC0>, <
# ...
